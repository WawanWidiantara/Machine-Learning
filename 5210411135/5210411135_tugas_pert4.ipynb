# %% [markdown]
# ## Tugas Pertemuan 4
# ***5210411135*** - I Gede Widiantara

# %% [markdown]
# ### Import all packages

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read File CSV

# %%
rawData = pd.read_csv('D:\Machine Learning/5210411135\data/tugas_pert4.csv')

# mengubah urutan kolom (mempermudah slicing features)
rawData = rawData[['jenis_sekolah', 'tingkat_sekolah', ' jumlah_sekolah ', ' jumlah_guru ', ' jumlah_murid ', ' jumlah_kelas ']]

rawData.head()
# Out:
#   jenis_sekolah tingkat_sekolah   jumlah_sekolah    jumlah_guru   \
# 0        Negeri              TK               9.0             58
# 1        Swasta              TK            1781.0           8646
# 2        Negeri              TK               9.0             58
# 3        Swasta              TK            1432.0          10064
# 4           NaN              TK               9.0            103
#
#     jumlah_murid    jumlah_kelas
# 0           521.0              35
# 1         92775.0            5179
# 2           673.0              35
# 3         81050.0            4524
# 4           836.0              35

# %% [markdown]
# ### Cek Dimensi & Missing Value

# %%
print(rawData.shape)
print(rawData.isnull().sum())
# Out:
# (50, 6)
# jenis_sekolah       1
# tingkat_sekolah     0
#  jumlah_sekolah     1
#  jumlah_guru        0
#  jumlah_murid       1
#  jumlah_kelas       0
# dtype: int64

# %% [markdown]
# ### Fill Missing Values

# %% [markdown]
# #### Manual

# %%
# fill missing value manual (data numerik)
rawData.loc[4, 'jenis_sekolah'] = 'Negeri'
rawData.isnull().sum()
# Out:
# jenis_sekolah       0
# tingkat_sekolah     0
#  jumlah_sekolah     1
#  jumlah_guru        0
#  jumlah_murid       1
#  jumlah_kelas       0
# dtype: int64

# %% [markdown]
# #### Simple Imputer

# %%
# fill missing value SimpleImputer (data nominal)
nominal = rawData.iloc[:,2:].values

imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp = imp.fit(nominal)

nominal = imp.transform(nominal)
rawData[[' jumlah_sekolah ',' jumlah_guru ', ' jumlah_murid ', ' jumlah_kelas ']] = nominal
rawData.isnull().sum()
# Out:
# jenis_sekolah       0
# tingkat_sekolah     0
#  jumlah_sekolah     0
#  jumlah_guru        0
#  jumlah_murid       0
#  jumlah_kelas       0
# dtype: int64

# %% [markdown]
# ### Encoding Data Numeric

# %%
# membuat data numeric
numData = rawData.copy()

lbenc = LabelEncoder()
for i in numData.columns.values:
    if numData[i].dtypes == 'object':
        numData[i] = lbenc.fit_transform(numData[i])

numData.head()
# Out:
#    jenis_sekolah  tingkat_sekolah   jumlah_sekolah    jumlah_guru   \
# 0              0                4               9.0           58.0
# 1              1                4            1781.0         8646.0
# 2              0                4               9.0           58.0
# 3              1                4            1432.0        10064.0
# 4              0                4               9.0          103.0
#
#     jumlah_murid    jumlah_kelas
# 0           521.0            35.0
# 1         92775.0          5179.0
# 2           673.0            35.0
# 3         81050.0          4524.0
# 4           836.0            35.0

# %% [markdown]
# ### Split Data Training & Data Testing

# %%
dataTT = numData.copy()

# Menentukan Label & Features
lb_y = dataTT.iloc[:,0].values
ft_x = dataTT.iloc[:,1:].values

# split
x_train, x_test, y_train, y_test = train_test_split(ft_x, lb_y, test_size=0.3, random_state=0)

dimensi = f'dimensi awal\t: {dataTT.shape}\ndimensi x_train\t: {x_train.shape}\ndimensi x_test\t: {x_test.shape}\ndimensi y_train\t: {y_train.shape}\ndimensi y_test\t: {y_test.shape}\n'
print(dimensi)
# Out:
# dimensi awal	: (50, 6)
# dimensi x_train	: (35, 5)
# dimensi x_test	: (15, 5)
# dimensi y_train	: (35,)
# dimensi y_test	: (15,)

# %% [markdown]
# ### Normalisasi

# %%
# pisahkan data numeric & nominal pada features
data_x = x_train.copy()
ft_nominal = data_x[:,1:]

# call minmaxscaler
mnmx = MinMaxScaler()
ft_nominal = mnmx.fit_transform(ft_nominal)

# menggabungkan kembali features
minmax_x = np.concatenate((data_x[:,0:1], ft_nominal), axis=1)
print(minmax_x) 

# membuat dataframe data hasil normalisasi
label_y = y_train.copy().reshape(-1,1) # ubah label menjadi array 2D
data = np.concatenate((label_y, minmax_x), axis=1)
cols = numData.columns.values
normalisasi = pd.DataFrame(data=data, columns=cols)
normalisasi.head()
# Out:
# [[4.00000000e+00 8.95164934e-01 3.56964108e-01 1.32119750e-01
#   3.15679019e-01]
#  [0.00000000e+00 9.93673746e-01 9.67090604e-01 9.85962739e-01
#   1.00000000e+00]
#  [2.00000000e+00 2.35427022e-01 4.21720202e-01 2.27670200e-01
#   2.44601535e-01]
#  [2.00000000e+00 2.44012653e-02 1.02190532e-01 6.33125163e-02
#   6.30143039e-02]
#  [3.00000000e+00 3.57433348e-01 4.10853245e-01 2.12885620e-01
#   3.57044237e-01]
#  [0.00000000e+00 3.75056484e-01 4.74306674e-01 3.19795312e-01
#   4.68824212e-01]
#  [1.00000000e+00 4.88025305e-02 2.37598985e-01 1.42087592e-01
#   1.40332468e-01]
#  [1.00000000e+00 4.88025305e-02 2.10380172e-01 1.34099759e-01
#   1.30502016e-01]
#  [0.00000000e+00 9.49841844e-01 9.27153680e-01 9.54284138e-01
#   9.48970012e-01]
#  [2.00000000e+00 2.44012653e-02 1.01676322e-01 6.28918607e-02
#   6.30143039e-02]
#  [3.00000000e+00 1.26073204e-01 4.44071167e-01 3.40892807e-01
#   2.56144033e-01]
#  [2.00000000e+00 2.31812020e-01 4.28439203e-01 2.39937010e-01
#   2.45540399e-01]
#  [4.00000000e+00 5.87437867e-03 2.19395975e-03 1.02159211e-03
#   2.42999945e-03]
#  [0.00000000e+00 3.59240850e-01 4.71907031e-01 3.00141605e-01
#   4.39940355e-01]
#  [3.00000000e+00 3.11342070e-01 3.87748106e-01 2.17485096e-01
#   3.30259016e-01]
#  [4.00000000e+00 6.38047899e-01 3.52679031e-01 1.26894684e-01
#   2.52333352e-01]
#  [0.00000000e+00 3.75056484e-01 4.71769908e-01 3.09725773e-01
#   4.68824212e-01]
#  [2.00000000e+00 2.44012653e-02 1.09560865e-01 6.44496731e-02
#   6.30143039e-02]
#  [2.00000000e+00 2.42657027e-01 4.09756265e-01 2.05697495e-01
#   2.49903352e-01]
#  [4.00000000e+00 8.00723000e-01 2.94401975e-01 1.42150767e-01
#   2.84089026e-01]
#  [0.00000000e+00 1.00000000e+00 1.00000000e+00 1.00000000e+00
#   1.00000000e+00]
#  [1.00000000e+00 1.57252598e-01 2.51242673e-01 8.18352294e-02
#   1.03827249e-01]
#  [3.00000000e+00 1.26525079e-01 3.87542422e-01 3.16664278e-01
#   2.56144033e-01]
#  [4.00000000e+00 0.00000000e+00 4.11367454e-04 2.51170938e-01
#   0.00000000e+00]
#  [3.00000000e+00 3.19475825e-01 4.13938501e-01 2.19993621e-01
#   3.34014470e-01]
#  [1.00000000e+00 4.88025305e-02 1.95468102e-01 1.27008707e-01
#   1.30502016e-01]
#  [3.00000000e+00 2.89652056e-01 3.83154503e-01 1.80555235e-01
#   2.74037665e-01]
#  [0.00000000e+00 4.07591505e-01 4.87093346e-01 3.33065223e-01
#   4.88319434e-01]
#  [4.00000000e+00 9.24988703e-01 3.54221658e-01 1.35122892e-01
#   3.26614017e-01]
#  [1.00000000e+00 1.65386353e-01 2.51551198e-01 9.56706375e-02
#   1.10123157e-01]
#  [2.00000000e+00 2.44012653e-02 1.03596037e-01 6.17516221e-02
#   6.30143039e-02]
#  [4.00000000e+00 6.43018527e-01 3.43011895e-01 1.24084150e-01
#   2.47915171e-01]
#  [4.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [2.00000000e+00 2.38138274e-01 4.20828905e-01 1.68587352e-01
#   2.46589717e-01]
#  [2.00000000e+00 2.44012653e-02 1.01950567e-01 5.85743628e-02
#   6.30143039e-02]]
#    jenis_sekolah  tingkat_sekolah   jumlah_sekolah    jumlah_guru   \
# 0            1.0              4.0          0.895165       0.356964
# 1            0.0              0.0          0.993674       0.967091
# 2            1.0              2.0          0.235427       0.421720
# 3            0.0              2.0          0.024401       0.102191
# 4            1.0              3.0          0.357433       0.410853
#
#     jumlah_murid    jumlah_kelas
# 0        0.132120        0.315679
# 1        0.985963        1.000000
# 2        0.227670        0.244602
# 3        0.063313        0.063014
# 4        0.212886        0.357044

# %% [markdown]
# ### Standarisasi

# %%
# pisahkan data numeric & nominal pada features
dt_x = x_train.copy()
ft_nom = dt_x[:,1:]

# call standardscaler
stsc = StandardScaler()
ft_nom = stsc.fit_transform(ft_nom)

# menggabungkan kembali features
stn_x = np.concatenate((dt_x[:,0:1], ft_nom), axis=1)
print(stn_x) 

# membuat dataframe data hasil standarisasi
label_y = y_train.copy().reshape(-1,1) # ubah label menjadi array 2D
dt = np.concatenate((label_y, stn_x), axis=1)
colm = numData.columns.values
standarisasi = pd.DataFrame(data=dt, columns=colm)
standarisasi.head()
# Out:
# [[ 4.00000000e+00  1.77802208e+00  2.60453719e-02 -4.32511614e-01
#    1.22010561e-01]
#  [ 0.00000000e+00  2.08618619e+00  2.58591339e+00  3.04823348e+00
#    2.82737128e+00]
#  [ 2.00000000e+00 -2.85829277e-01  2.97738297e-01 -4.29941445e-02
#   -1.58983647e-01]
#  [ 2.00000000e+00 -9.45978992e-01 -1.04289154e+00 -7.13008664e-01
#   -8.76861626e-01]
#  [ 3.00000000e+00  9.58418644e-02  2.52144514e-01 -1.03264421e-01
#    2.85541767e-01]
#  [ 0.00000000e+00  1.50972140e-01  5.18371938e-01  3.32559716e-01
#    7.27447189e-01]
#  [ 1.00000000e+00 -8.69644763e-01 -4.74767104e-01 -3.91877073e-01
#   -5.71195820e-01]
#  [ 1.00000000e+00 -8.69644763e-01 -5.88967306e-01 -4.24439982e-01
#   -6.10059044e-01]
#  [ 0.00000000e+00  1.94906729e+00  2.41835264e+00  2.91909365e+00
#    2.62563184e+00]
#  [ 2.00000000e+00 -9.45978992e-01 -1.04504897e+00 -7.14723493e-01
#   -8.76861626e-01]
#  [ 3.00000000e+00 -6.27919707e-01  3.91514786e-01  4.18564992e-01
#   -1.13352109e-01]
#  [ 2.00000000e+00 -2.97138051e-01  3.25928776e-01  7.01228296e-03
#   -1.55271991e-01]
#  [ 4.00000000e+00 -1.00393646e+00 -1.46244064e+00 -9.66941567e-01
#   -1.11637262e+00]
#  [ 0.00000000e+00  1.01496252e-01  5.08303910e-01  2.52440135e-01
#    6.13259178e-01]
#  [ 3.00000000e+00 -4.83450112e-02  1.55203787e-01 -8.45143663e-02
#    1.79650399e-01]
#  [ 4.00000000e+00  9.73685489e-01  8.06675055e-03 -4.53811927e-01
#   -1.28417067e-01]
#  [ 0.00000000e+00  1.50972140e-01  5.07728594e-01  2.91510601e-01
#    7.27447189e-01]
#  [ 2.00000000e+00 -9.45978992e-01 -1.01196831e+00 -7.08372972e-01
#   -8.76861626e-01]
#  [ 2.00000000e+00 -2.63211728e-01  2.47541987e-01 -1.32567270e-01
#   -1.38023707e-01]
#  [ 4.00000000e+00  1.48258034e+00 -2.36442499e-01 -3.91619535e-01
#   -2.87575381e-03]
#  [ 0.00000000e+00  2.10597654e+00  2.72398920e+00  3.10545726e+00
#    2.82737128e+00]
#  [ 1.00000000e+00 -5.30381527e-01 -4.17523173e-01 -6.37499650e-01
#   -7.15513747e-01]
#  [ 3.00000000e+00 -6.26506110e-01  1.54340814e-01  3.19795860e-01
#   -1.13352109e-01]
#  [ 4.00000000e+00 -1.02231322e+00 -1.46991975e+00  5.28081043e-02
#   -1.12597926e+00]
#  [ 3.00000000e+00 -2.29002685e-02  2.65089121e-01 -7.42882057e-02
#    1.94497024e-01]
#  [ 1.00000000e+00 -8.69644763e-01 -6.51532909e-01 -4.53347102e-01
#   -6.10059044e-01]
#  [ 3.00000000e+00 -1.16197659e-01  1.35930705e-01 -2.35061288e-01
#   -4.26123086e-02]
#  [ 0.00000000e+00  2.52751111e-01  5.72020144e-01  3.86655352e-01
#    8.04518639e-01]
#  [ 4.00000000e+00  1.87131947e+00  1.45390542e-02 -4.20269116e-01
#    1.65240439e-01]
#  [ 1.00000000e+00 -5.04936784e-01 -4.16228713e-01 -5.81098731e-01
#   -6.90623817e-01]
#  [ 2.00000000e+00 -9.45978992e-01 -1.03699455e+00 -7.19371748e-01
#   -8.76861626e-01]
#  [ 4.00000000e+00  9.89235054e-01 -3.24930192e-02 -4.65269247e-01
#   -1.45883684e-01]
#  [ 4.00000000e+00 -1.02231322e+00 -1.47164570e+00 -9.71106152e-01
#   -1.12597926e+00]
#  [ 2.00000000e+00 -2.77347696e-01  2.93998744e-01 -2.83849119e-01
#   -1.51123670e-01]
#  [ 2.00000000e+00 -9.45978992e-01 -1.04389834e+00 -7.32324047e-01
#   -8.76861626e-01]]
#    jenis_sekolah  tingkat_sekolah   jumlah_sekolah    jumlah_guru   \
# 0            1.0              4.0          1.778022       0.026045
# 1            0.0              0.0          2.086186       2.585913
# 2            1.0              2.0         -0.285829       0.297738
# 3            0.0              2.0         -0.945979      -1.042892
# 4            1.0              3.0          0.095842       0.252145
#
#     jumlah_murid    jumlah_kelas
# 0       -0.432512        0.122011
# 1        3.048233        2.827371
# 2       -0.042994       -0.158984
# 3       -0.713009       -0.876862
# 4       -0.103264        0.285542
